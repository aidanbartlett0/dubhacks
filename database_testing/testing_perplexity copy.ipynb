# %%
import requests
import ast
import re
import hashlib

content = '''
Welcome Back to the University of Washington!
The Returning Student Process is designed for undergraduate or professional-level students wishing to return to the University of Washington after an absence of one quarter or more (excluding summer quarter).
The following steps will guide you through the process to reactivate your student account and prepare you to register for a future quarter. Once you have submitted your Returning Student Request Form, you’ll be able to clear any holds you may have on your registration, and then confirm your intention to enroll through the Enrollment Confirmation System.
You may request to return to the University of Washington if you:

Have been away for more than one quarter (excluding summer quarter). Withdrawing from one quarter and not attending the subsequent quarter constitutes an absence of two consecutive quarters, which triggers the need to submit the Returning Student Request Form, AND
Have not obtained a degree in their last enrolled student category, either from the University of Washington or from another institution.

The ability to return as a student to the University of Washington is granted at the discretion of the University.
Eligibility factors which may be considered include, but are not limited to:

space availability in the major in which you were previously enrolled
activities during the period in which you were not enrolled
prior disciplinary action

Ready to Return? Get Started in Five Easy Steps
Step One: Returning Student Request Form
Complete and submit the Returning Student Request Form by the deadline date and time. We’ll collect your current contact information and additional data that we need to reactivate your student account.
This form is only for undergraduate and professional students who have not completed their UW degree.

Do not complete this form if you:

have already graduated
are a Graduate student
are a Non-Matriculated student



Returning Student Request Form
Step Two: Email Confirmation
Watch for an email from your campus registration team confirming that your Returning Student Request Form has been processed.

UW Seattle: regoff@uw.edu
UW Tacoma: reguwt@uw.edu
UW Bothell: uwbreg@uw.edu

Once you have been notified that your Returning Student Request Form has been processed you will receive an email prompting you to confirm your enrollment for the returning quarter you indicated.
Step Three: Check and Clear Any Registration Holds
After you receive an offer to return, log in to Log into MyUW and check on any holds that may prevent you from registering. These could be placed on your account for tuition and fees still owed from a prior quarter, behavioral holds, departmental holds related to satisfactory academic progress, or any other holds associated with blocking registration until you take the required action.
We encourage you to resolve whatever registration holds might be on your account first before proceeding to Step Five.
Step Four: Meet with your Adviser
To prepare for your transition to campus, meet with your academic adviser to plan your class schedule for your return quarter. Remember to check Log into MyUW for information about registering for classes.
Step Five: Confirm Your Quarter to Return
When you are ready, confirm your enrollment for the quarter you wish to return to the UW.
You will be required to pay a non-refundable Enrollment Confirmation Fee:



UW Bothell
UW Seattle
UW Tacoma




$60
$80
$60



Completing the Enrollment Confirmation step is required before you will be allowed to register and to continue your studies.

Residency Alert
Be advised that students returning to the University of Washington may not necessarily be readmitted under their previous residency classification. It is highly suggested that after you register for classes you check your tuition statement to ensure the tuition rate and fees are charged correctly. Students should be prepared to complete any necessary application and documents required to correct their classification with the Residency Office.

Returning Student Deadlines
You must complete all steps of the Returning Student process, including registering for classes for your return quarter by the end of the Returning Student Process Deadline day of the quarter you wish to return.



Quarter
Step One: Application Request Submission Deadline @ 5pm
Steps Two-Five: Completion Deadline*




Autumn 2024
September 24, 2024
October 4, 2024


Winter 2025
January 3, 2025
January 17, 2025


Spring 2025
March 28, 2025
April 4, 2025


Summer 2025
June 20, 2025
July 3, 2025


Autumn 2025
September 22, 2025
October 3, 2025


Winter 2026
January 2, 2026
January 16, 2026



UW Bothell and UW Tacoma
Returning Students to UW Bothell and UW Tacoma may have unique deadlines and other requirements for resuming your studies. Check with your respective campus registration team for more information. If you have any questions on the Returning Student Process, email your campus registration team.



Campus
Registration Team
Resource
EC Fee




UW Bothell
uwbreg@uw.edu
Returning Student Process
$60


UW Tacoma
reguwt@uw.edu
Returning Student Re-enrollment
$60



Graduate Students
Students previously registered in the Graduate School who have failed to maintain graduate student status (on-leave status was not secured or registration was not maintained) but wish to resume studies within the same degree program must file a request for reinstatement to the Graduate School.
Graduate students who are returning from official on-leave status do not complete the Returning Student Request Form. Review the Graduate On-Leave Status for on-leave eligibility, the procedure for requesting leave, and information about reinstatement.
For questions regarding on-leave status or the graduate reinstatement process, please contact the Graduate Program Advisor within your graduate program and/or Graduate Enrollment Management Services at uwgrad@uw.edu or 206-685-2630.
Productivity Platforms
Please be aware that the UW G Suite and/or UW Office 365 email & productivity platform account(s) and data that you create with your UW email address are temporary and will expire when you graduate and/or separate from the UW. However, you do have the ability to forward your UW email address to a personal, non-UW email address as a student and upon separation from the UW.
'''

# %%
def call(content):
    perplexity_api_key = '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'
    url = "https://api.perplexity.ai/chat/completions"

    payload = {
        "model": "llama-3.1-sonar-small-128k-online",
        "messages": [
            {
                "role": "system",
                "content": "Your purpose is to summarize and pre-processs text from a website. Be clear and precise. Generate a list of 10 keywords for the given \"SITE CONTENT\" and a 3 paragraph summary of the \"SITE CONTENT\". The summary should not be bulletted lists, it should be 3 paragraphs of general summary text and should not include any URLS. The keywords should not be more than 3 tokens each and should not include URLs. Format your output to be EXACTLY like this: \"##KEYS## [<KEY>, <KEY>, <KEY>, <KEY>, <KEY>, <KEY>, <KEY>, <KEY>, <KEY>, <KEY>] ##SUMMARY##\". Exclude the rest of the \"SITE CONTENT\" from the output."
            },
            {
                "role": "user",
                "content": f'SITE CONTENT: \"{content}\"'
            }
        ],
        "max_tokens": 1000,
        "temperature": 0.2,
        "top_p": 0.9,
        "return_citations": True,
        "search_domain_filter": ["perplexity.ai"],
        "return_images": False,
        "return_related_questions": False,
        "search_recency_filter": "month",
        "top_k": 0,
        "stream": False,
        "presence_penalty": 0,
        "frequency_penalty": 1
    }
    headers = {
        "Authorization": f"Bearer {perplexity_api_key}",
        "Content-Type": "application/json"
    }

    response = requests.request("POST", url, json=payload, headers=headers)
    text = response.text
    lit_text = ast.literal_eval(text)

    chat_response = lit_text['choices'][0]['message']['content']

    return(chat_response)

# %%
text = call(content)
print(text)
# Out:
# ## KEYS ## [Returning Student, Enrollment Confirmation, Registration Holds, Academic Adviser, Residency Classification, Enrollment Fee, Returning Student Deadlines, Graduate On-Leave Status, Productivity Platforms, Residency Office] ## SUMMARY ##
#
# The University of Washington has a specific process for undergraduate and professional students who wish to return after an absence of one quarter or more. The Returning Student Process involves several steps to reactivate the student account and prepare for registration. Students must submit the Returning Student Request Form, which includes providing current contact information and other necessary data. Once processed, they will receive an email prompting them to confirm their enrollment for the returning quarter.
#
# After receiving notification, students need to check and clear any registration holds that may prevent them from registering. These holds could be related to tuition and fees still owed, behavioral issues, or departmental holds associated with satisfactory academic progress. It is crucial to resolve these holds before proceeding with the next steps.
#
# To prepare for their transition to campus, students should meet with their academic adviser to plan their class schedule for the return quarter. They should also check Log into MyUW for information about registering for classes. Finally, students must confirm their enrollment for the quarter they wish to return to by paying a non-refundable Enrollment Confirmation Fee, which varies by campus.
#
# Additionally, students returning to the University of Washington may not necessarily be readmitted under their previous residency classification. It is highly suggested that after registering for classes, they check their tuition statement to ensure the tuition rate and fees are charged correctly. If necessary, students should complete any required applications and documents to correct their classification with the Residency Office.
#
# The Returning Student Process deadlines vary by quarter, with specific submission and completion dates provided for each quarter. Graduate students who have failed to maintain graduate student status but wish to resume studies within the same degree program must file a request for reinstatement to the Graduate School. For questions regarding on-leave status or the graduate reinstatement process, graduate students should contact the Graduate Program Advisor or Graduate Enrollment Management Services.

# %%
def extract_keywords(text):
    keywords = text.split("##")[2]
    keywords = keywords.split(',')
    keys = [re.sub(r'[^a-zA-Z0-9\s]', '', i).strip() for i in keywords]
    return keys
print(extract_keywords(text))

def generate_hash(keywords):
    keywords_str = ' '.join(keywords)
    hash_object = hashlib.sha256(keywords_str.encode('utf-8'))
    hex_dig = hash_object.hexdigest()
    return hex_dig[:25]
print(generate_hash(extract_keywords(text)))

def extract_summary(text):
    summary = text.split("##")[4]
    return summary
print(extract_summary(text))
# Out:
# ['Returning Student', 'Enrollment Confirmation', 'Registration Holds', 'Academic Adviser', 'Residency Classification', 'Enrollment Fee', 'Returning Student Deadlines', 'Graduate OnLeave Status', 'Productivity Platforms', 'Residency Office']
# 907753a1cfa0a9a9f65f42ec1
#
#
# The University of Washington has a specific process for undergraduate and professional students who wish to return after an absence of one quarter or more. The Returning Student Process involves several steps to reactivate the student account and prepare for registration. Students must submit the Returning Student Request Form, which includes providing current contact information and other necessary data. Once processed, they will receive an email prompting them to confirm their enrollment for the returning quarter.
#
# After receiving notification, students need to check and clear any registration holds that may prevent them from registering. These holds could be related to tuition and fees still owed, behavioral issues, or departmental holds associated with satisfactory academic progress. It is crucial to resolve these holds before proceeding with the next steps.
#
# To prepare for their transition to campus, students should meet with their academic adviser to plan their class schedule for the return quarter. They should also check Log into MyUW for information about registering for classes. Finally, students must confirm their enrollment for the quarter they wish to return to by paying a non-refundable Enrollment Confirmation Fee, which varies by campus.
#
# Additionally, students returning to the University of Washington may not necessarily be readmitted under their previous residency classification. It is highly suggested that after registering for classes, they check their tuition statement to ensure the tuition rate and fees are charged correctly. If necessary, students should complete any required applications and documents to correct their classification with the Residency Office.
#
# The Returning Student Process deadlines vary by quarter, with specific submission and completion dates provided for each quarter. Graduate students who have failed to maintain graduate student status but wish to resume studies within the same degree program must file a request for reinstatement to the Graduate School. For questions regarding on-leave status or the graduate reinstatement process, graduate students should contact the Graduate Program Advisor or Graduate Enrollment Management Services.

# %%
'''
DEPREICATED - old prompt
def extract_keywords(text):
    keywords = text.split('###')[1]
    lines = text.split('\n')
    keywords = []
    
    for i in lines:
        if i.startswith('- '):
            keyword = i[2:].strip()
            keywords.append(keyword)

    return keywords
x = extract_keywords(text)
x
'''
# Out:
# ['Returning Student Process',
#  'University of Washington',
#  'Student Account Reactivation',
#  'Enrollment Confirmation System',
#  'Registration Holds',
#  'Academic Adviser',
#  'Enrollment Confirmation Fee',
#  'Residency Classification',
#  'Returning Student Deadlines']

# %%
'''
DEPRIATED - old prompt
def extract_sumary(text):
    summary = text.split('###')[2]
    if summary.startswith(' Summary:\n\n'):
        summary = summary[14:].strip()
    return summary
x = extract_sumary(text)
print(x)'''
# Out:
# Returning Student Process at the University of Washington is designed for undergraduate or professional-level students who have been away from the university for one quarter or more, excluding summer quarters. To reactivate their student account and prepare for registration, students must complete a Returning Student Request Form, which includes providing current contact information and additional data needed to reactivate their account. After submitting the form, students will receive an email confirming the processing of their request and prompting them to confirm their enrollment for the returning quarter.
#
# Students are then required to check and clear any registration holds on their account, which could include tuition and fees still owed, behavioral holds, or departmental holds related to satisfactory academic progress. Meeting with an academic adviser is also a crucial step to plan their class schedule for the return quarter. Finally, students must confirm their enrollment by paying a non-refundable Enrollment Confirmation Fee, which varies by campus (UW Bothell: $60, UW Seattle: $80, UW Tacoma: $60).
#
# It is important to note that students returning to the University of Washington may not necessarily be readmitted under their previous residency classification. Therefore, they should check their tuition statement after registering for classes to ensure the correct tuition rate and fees are charged. Students may need to complete any necessary application and documents required to correct their classification with the Residency Office.
#
# The Returning Student Process has specific deadlines for each quarter, and students must complete all steps, including registering for classes, by the end of the Returning Student Process Deadline day of the quarter they wish to return. For unique deadlines and requirements, students should check with their respective campus registration team. Graduate students who have failed to maintain graduate student status must file a request for reinstatement to the Graduate School instead of following the Returning Student Process.

# %%
'''
To delete everything in the uwwebsites container
'''

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Connect to MongoDB
uri = "mongodb+srv://aidanb04:dubhackshacker@dubhacks.qxk8w.mongodb.net/"
client = MongoClient(uri, server_api=ServerApi('1'))

db = client['dubhacks']
uwwebsites = db['uwwebsites']

# result = uwwebsites.delete_many({})

# print(f"Documents deleted: {result.deleted_count}")
existing_urls = set([doc['url'] for doc in uwwebsites.find()])
print(existing_urls)
# Out:
# {'https://www.washington.edu/students/'}
